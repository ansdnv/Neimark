# %% [markdown]
# https://docs.google.com/spreadsheets/d/1Zq-j0DU55U2KM_phC0zy1ITitIQyUufAWo5Ro-C_sKE/edit?usp=sharing
#
# https://docs.google.com/spreadsheets/d/1yylebUuknrb0R5nUhNVUNqXnttetbV1OTwV0RkiR2Bw/edit?usp=sharing
#
# # до 20 января
# https://docs.google.com/document/d/16N_hnzBU-gqnWZc4pfd4qN8mWSJiLrWanrHDwUfSE08/edit
#
# Вы должны выбрать датасет для решения задачи классификации или регрессии. Рекомендую брать понравившийся датасет с kaggle. Например,
#
# #### Классификация:
# - https://www.kaggle.com/purumalgi/music-genre-classification
# - https://www.kaggle.com/rashikrahmanpritom/177k-english-song-data-from-20082017
#
# - https://www.kaggle.com/sagnik1511/car-insurance-data
# - https://www.kaggle.com/teertha/personal-loan-modeling
#
# - https://www.kaggle.com/fedesoriano/heart-failure-prediction/version/1
# - https://www.kaggle.com/fedesoriano/stroke-prediction-dataset
#
# - https://www.kaggle.com/shivan118/hranalysis?select=train.csv
#
# - https://www.kaggle.com/shivamb/real-or-fake-fake-jobposting-prediction?select=fake_job_postings.csv
#
# - https://www.kaggle.com/jsphyg/weather-dataset-rattle-package
#
# - https://www.kaggle.com/mssmartypants/water-quality
#
# - https://www.kaggle.com/code/gauravduttakiit/covid-19-sentiment-analysis-on-train-data/
#
# - https://www.kaggle.com/kaushiksuresh147/customer-segmentation?select=Train.csv
# - https://www.kaggle.com/lucidlenn/sloan-digital-sky-survey
#
# #### Регрессия:
# - https://www.kaggle.com/naveengowda16/logistic-regression-heart-disease-prediction
#
# #### Придумать самой:
# - https://www.kaggle.com/sobhanmoosavi/us-accidents/version/10
# - https://www.kaggle.com/crowdflower/twitter-user-gender-classification
# - https://www.kaggle.com/datasets/raghadalharbi/all-products-available-on-sephora-website
#
# Рекомендуется брать датасет с несколькими тысячами-десятками тысяч объектов и несколькими десятками признаков.
#
# Задачу надо решать в Jupyter notebook и выложить на гит.
#
# + Загрузите данные
# + Опишите задачу словами. В том числе напишите, что значит каждый признак
# - Разбейте данные на обучающую и тестовую выборки
# - Визуализируйте данные из обучающей выборки. В частности, имеет смысл построить диаграммы рассеивания для количественных признаков. Построить гистограммы распределений и т.п. Вычислить основные характеристики (среднее, разброс, корреляционную матрицу и т.д.). Интерпретируйте результаты
# + Обработать пропущенные значения (или убедиться, что их нет)
# - Исключить нерелевантные признаки (объяснить, как вы их нашли)
# - Если необходимо, то обработать коррелированные признаки
# + Обработать категориальные признаки
# - Провести масштабирование (или объяснить, почему в вашем случае оно не нужно)
# - Вам может понадобиться другая предобработка. Например, если в вашем датасете есть текстовые признаки с уникальными значениями (например, аннотации товаров, отзывы пользователей, другие тексты), как в двух последних датасетах из перечисленных, то вам понадобится этап извлечения признаков, т.е. простые методы NLP, как, например, bag-of-words. Воспользуйтесь библиотеками re, nltk
# - После шагов 5–10 разумно вернутся к шагу 4 (а может, возвращаться к нему после каждого из этапов 5–10.
# - Попробуйте как минимум 3 метода классификации (регрессии). Объясните ваш выбор. Найдите значения метрик на обучающей и тестовой выборке. Сделайте вывод.
# - На одном из методов (объясните выбор) найдите оптимальное значение параметров. Постройте график зависимости ошибок (на обучающей выборке и валидационной/CV) от значения гиперпарамтра. Для найденного оптимального значения параметра (параметров) снова обучите модель. Сделайте вывод.
# - Довольны ли вы результатами? В частности, если классы не сбалансированы, то результат может оказаться неприемлемым. В этом случае можете применить методы балансировки из библиотеки imbalanced-learn.
# - Сделать общие выводы
#
# Вы можете пользоваться готовыми примерами решения подобных задач. Например, здесь есть основные шаги, правда мало комментариев: https://github.com/NikolaiZolotykh/MachineLearningCourse/blob/master/VADII_06_%D0%9E%D1%86%D0%B5%D0%BD%D0%BA%D0%B0_%D1%81%D1%82%D0%BE%D0%B8%D0%BC%D0%BE%D1%81%D1%82%D0%B8_%D0%BA%D0%B2%D0%B0%D1%80%D1%82%D0%B8%D1%80%D1%8B.ipynb
# Обратите внимание, что это задача восстановления регрессии - большинство же из вас выберет классификацию

# %%
import numpy as np              # Одномерные и многомерные массивы (array)
import pandas as pd             # Таблицы и временные ряды (dataframe, series)
import matplotlib.pyplot as plt # Научная графика
import seaborn as sns           # Еще больше красивой графики для визуализации данных
import sklearn                  # Алгоритмы машинного обучения

# %% [markdown]
# # Прогнозирование сердечной недостаточности

# %% [markdown]
# ### 1. Загрузка данных.

# %%
filename = 'heart.csv'
df = pd.read_csv(filename)

# %% [markdown]
# ### 2. Описание задачи и датасета.

# %% [markdown]
# Рассмотрим полученный датасет:

# %%
df
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 0     40   M           ATA        140          289          0     Normal
# 1     49   F           NAP        160          180          0     Normal
# 2     37   M           ATA        130          283          0         ST
# 3     48   F           ASY        138          214          0     Normal
# 4     54   M           NAP        150          195          0     Normal
# ..   ...  ..           ...        ...          ...        ...        ...
# 913   45   M            TA        110          264          0     Normal
# 914   68   M           ASY        144          193          1     Normal
# 915   57   M           ASY        130          131          0     Normal
# 916   57   F           ATA        130          236          0        LVH
# 917   38   M           NAP        138          175          0     Normal
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# ...

# %% [markdown]
# Датасет содержит 918 записей о пациентах, каждая из которых содержит следующие 12 признаков:
# 1. Age - возраст пациента в годах
# 2. Sex - пол пациента (M: мужчина, F: женщина)
# 3. ChestPainType - тип боли в груди (TA: Типичная стенокардия, ATA: Атипичная стенокардия, NAP: Неангинальная боль, ASY: Бессимптомная)
# 4. RestingBP - артериальное давление в покое (мм. рт. ст.)
# 5. Cholesterol - сывороточный холестерин (мг/дл)
# 6. FastingBS - уровень сахара в крови натощак (1: если уровень сахара > 120 мг/дл, 0: в противном случае)
# 7. RestingECG - результаты электрокардиограммы в покое (Normal - нормальный, ST - имеются аномальные волны ST-T (инверсия зубца Т и/или элевация или депрессия сегмента ST > 0,05 мВ), LVH - показывает вероятную или определенную гипертрофию левого желудочка по критериям Эстеса)
# 8. MaxHR - достижение максимальной частоты сердечных сокращений (числовое значение от 60 до 202)
# 9. ExerciseAngina - стенокардия, вызванная физической нагрузкой (Y - да, N - нет)
# 10. Oldpeak - oldpeak = ST (числовое значение, измеренное в депрессии)
# 11. ST_Slope: наклон сегмента ST пикового упражнения (Up: восходящий, Flat: плоский, Down: нисходящий)
# 12. HeartDisease: выходной класс (1: болезнь сердца, 0: нормальный)

# %% [markdown]
# Необходимо обучить на данном датасете модель, которая могла бы при наличии первых 11 признаков, определять есть ли у человека болезнь сердечной недостаточности.

# %% [markdown]
# ### 3. Определение дисбаланса классов.

# %%
have_HeartDisease = df[df['HeartDisease'] == 1].shape[0]
dont_have_HeartDisease = df[df['HeartDisease'] == 0].shape[0]

print('Количество людей, имеющих болезни сердечной недостаточности, в датасете: ', have_HeartDisease)
print('Количество людей, не имеющих болезни сердечной недостаточности, в датасете: ', dont_have_HeartDisease)
# Out:
# Количество людей, имеющих болезни сердечной недостаточности, в датасете:  508
# Количество людей, не имеющих болезни сердечной недостаточности, в датасете:  410

# %%
sns.countplot(x=df['HeartDisease'])
pass

# %% [markdown]
# Можно сделать вывод о том, что работаем со сбалансированным классом в датасете.

# %% [markdown]
# ### 4. Обработка категориальных признаков.

# %% [markdown]
# Признаки Age, RestingBP, Cholesterol, MaxHR, Oldpeak - числовые; Sex, FastingBS, ExerciseAngina, HeartDisease - бинарные; ChestPainType, RestingECG, ST_Slope - категориальные. Требуется предсказать целевой бинарный признак HeartDisease по остальным признакам - это задача бинарной классификации.

# %% [markdown]
# Заменим у категориальных и бинарных признаков тип на специальный:

# %%
df['ChestPainType'] = df['ChestPainType'].astype('category')
df['RestingECG'] = df['RestingECG'].astype('category')
df['ST_Slope'] = df['ST_Slope'].astype('category')

df['Sex'] = df['Sex'].astype('category')
df['FastingBS'] = df['FastingBS'].astype('category')
df['ExerciseAngina'] = df['ExerciseAngina'].astype('category')
df['HeartDisease'] = df['HeartDisease'].astype('category')

# %% [markdown]
# Информация о числовых признаках:

# %%
df.describe()
# Out:
#               Age   RestingBP  Cholesterol       MaxHR     Oldpeak
# count  918.000000  918.000000   918.000000  918.000000  918.000000
# mean    53.510893  132.396514   198.799564  136.809368    0.887364
# std      9.432617   18.514154   109.384145   25.460334    1.066570
# min     28.000000    0.000000     0.000000   60.000000   -2.600000
# 25%     47.000000  120.000000   173.250000  120.000000    0.000000
# 50%     54.000000  130.000000   223.000000  138.000000    0.600000
# 75%     60.000000  140.000000   267.000000  156.000000    1.500000
# max     77.000000  200.000000   603.000000  202.000000    6.200000

# %% [markdown]
# Информация о категориальных признаках:

# %%
df.describe(include=['category'])
# Out:
#         Sex ChestPainType  FastingBS RestingECG ExerciseAngina ST_Slope  \
# count   918           918        918        918            918      918
# unique    2             4          2          3              2        3
# top       M           ASY          0     Normal              N     Flat
# freq    725           496        704        552            547      460
#
#         HeartDisease
# count            918
# unique             2
# top                1
# freq             508

# %% [markdown]
# ### 5. Обработка пропущенных значений

# %% [markdown]
# Проверим датасет на пропущенные значения:

# %%
df.isnull().sum()
# Out:
# Age               0
# Sex               0
# ChestPainType     0
# RestingBP         0
# Cholesterol       0
# FastingBS         0
# RestingECG        0
# MaxHR             0
# ExerciseAngina    0
# Oldpeak           0
# ST_Slope          0
# HeartDisease      0
# dtype: int64

# %% [markdown]
# Пропущенных значений нет.

# %% [markdown]
# ### 6. Визуализация данных и борьба с выбросами.

# %% [markdown]
# Построим диаграммы рассеивания для всех количественных признаков:

# %%
pd.plotting.scatter_matrix(df, figsize = (15, 15))
pass

# %% [markdown]
# Заметим, что у признака Cholesterol довольно много нулевых значений. Судя по всему это выброс, поскольку теоретически такого значения уровня холестерина в крови у человека не может быть. Удалим все нулевые значения.
#
# Также меня очень беспокоит высокая распространненость нулевого значения признака Oldpeak, но с ним к сожалению сложно разобраться в силу недостаточных познаний в медицине, поэтому оставим данный признак в неизменном виде.

# %%
outlers = df[df['Cholesterol'] == 0]
persentage_of_outlers = outlers.shape[0] / df.shape[0] * 100
print('Процент выбросов:', persentage_of_outlers, '%')
# Out:
# Процент выбросов: 18.736383442265794 %

# %%
df = df[df['Cholesterol'] > 0]

# %% [markdown]
# Построим корреляционную матрицу и для удобства визуализируем ее:

# %%
corr_mat = df.corr()
sns.heatmap(corr_mat, square=True, vmin=-1, vmax=1, cmap='coolwarm')
pass
